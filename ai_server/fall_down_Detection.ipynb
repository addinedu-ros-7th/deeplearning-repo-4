# %%
import cv2
import cvzone
import math
from ultralytics import YOLO

cap = cv2.VideoCapture('/home/wani/Downloads/fall.mp4')

model = YOLO('yolov8s.pt')

classnames = []
with open('/home/wani/Downloads/classes.txt', 'r') as f:
    classnames = f.read().splitlines()


while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame, (980,740))

    results = model(frame)

    for info in results:
        parameters = info.boxes
        for box in parameters:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            confidence = box.conf[0]
            class_detect = box.cls[0]
            class_detect = int(class_detect)
            class_detect = classnames[class_detect]
            conf = math.ceil(confidence * 100)


            # implement fall detection using the coordinates x1,y1,x2
            height = y2 - y1
            width = x2 - x1
            threshold  = height - width

            if conf > 80 and class_detect == 'person':
                cvzone.cornerRect(frame, [x1, y1, width, height], l=30, rt=6)
                cvzone.putTextRect(frame, f'{class_detect}', [x1 + 8, y1 - 12], thickness=2, scale=2)
            
            if threshold < 0:
                cvzone.putTextRect(frame, 'Fall Down!!!', [height, width], thickness=2, scale=2)
            
            else:pass


    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('t'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x640 2 persons, 11.7ms
# Speed: 2.5ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.8ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 8.1ms
# Speed: 3.5ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.8ms
# Speed: 3.6ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 3.8ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.6ms
# Speed: 4.9ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 3.7ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.4ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.6ms
# Speed: 4.0ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 refrigerator, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 suitcase, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 suitcase, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 suitcase, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 car, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tennis racket, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 skateboard, 1 tv, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 skateboard, 1 tv, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 skateboards, 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 skateboard, 1 tv, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 3.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)

# %%
import cv2
import cvzone
import math
from ultralytics import YOLO

# 웹캠으로 비디오 캡처 시작 (0번은 기본 웹캠)
cap = cv2.VideoCapture(0)

# YOLO 모델 로드
model = YOLO('yolov8s.pt')

classnames = []
with open('/home/wani/Downloads/classes.txt', 'r') as f:
    classnames = f.read().splitlines()

while True:
    ret, frame = cap.read()
    if not ret:
        print("웹캠 연결 오류")
        break

    # 프레임 크기 조정 (웹캠 해상도에 맞게 조정 가능)
    frame = cv2.resize(frame, (980, 740))

    # 모델을 통해 결과 추론
    results = model(frame)

    # 추론 결과에서 객체 감지
    for info in results:
        parameters = info.boxes
        for box in parameters:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            confidence = box.conf[0]
            class_detect = box.cls[0]
            class_detect = int(class_detect)
            class_detect = classnames[class_detect]
            conf = math.ceil(confidence * 100)

            # 낙상 감지 로직 (사람이 감지되면 감지 박스 표시)
            height = y2 - y1
            width = x2 - x1
            threshold = height - width

            if conf > 80 and class_detect == 'person':  # 사람 클래스에 대해 낙상 감지
                cvzone.cornerRect(frame, [x1, y1, width, height], l=30, rt=6)
                cvzone.putTextRect(frame, f'{class_detect}', [x1 + 8, y1 - 12], thickness=2, scale=2)

                # 낙상 감지: 고관절(y 좌표)이 무릎(y 좌표)보다 낮을 때
                if threshold < 0:
                    cvzone.putTextRect(frame, 'Fall Down!!!', [x1, y2], thickness=2, scale=2)

    # 실시간 영상 출력
    cv2.imshow('Real-time Fall Detection', frame)

    # 't' 키를 눌러서 종료
    if cv2.waitKey(1) & 0xFF == ord('t'):
        break

# 웹캠과 창 닫기
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x640 1 person, 2 ties, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tie, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tie, 1 bed, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 tie, 2 beds, 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 2 ties, 1 bed, 1 laptop, 10.7ms
# Speed: 2.6ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tie, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tie, 1 laptop, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tie, 1 cell phone, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tie, 1 cell phone, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 bed, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 tie, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 tie, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 tie, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 tie, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tie, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tie, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 tie, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 tie, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 tie, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 2 ties, 10.1ms
# Speed: 1.6ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 airplane, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 airplane, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 airplane, 10.2ms
# Speed: 3.9ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 2 airplanes, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 2 airplanes, 1 bird, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 airplane, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 airplane, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 airplane, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 backpack, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 laptop, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 4 chairs, 2 tvs, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 4 chairs, 2 tvs, 1 laptop, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 5 chairs, 2 tvs, 1 laptop, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 couch, 4 tvs, 1 laptop, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 cup, 1 chair, 3 tvs, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 2 chairs, 1 dining table, 4 tvs, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 chair, 3 tvs, 2 laptops, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 chair, 1 tv, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 cup, 4 chairs, 6 tvs, 1 laptop, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 cup, 4 chairs, 8 tvs, 1 laptop, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 2 cups, 3 chairs, 5 tvs, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 2 cups, 2 chairs, 7 tvs, 2 laptops, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 backpack, 1 chair, 10 tvs, 1 laptop, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 backpack, 1 cup, 1 chair, 3 tvs, 1 laptop, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 backpack, 1 cup, 1 chair, 3 tvs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 backpack, 1 cup, 2 dining tables, 2 tvs, 1 laptop, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 1 backpack, 1 tv, 1 laptop, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 1 bowl, 1 chair, 1 dining table, 1 tv, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 backpack, 1 cup, 2 dining tables, 1 tv, 1 laptop, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 1 chair, 1 dining table, 1 tv, 1 laptop, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 backpack, 2 cups, 1 chair, 1 dining table, 1 tv, 3 laptops, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 2 chairs, 1 dining table, 3 tvs, 2 laptops, 1 remote, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 cup, 2 chairs, 4 tvs, 3 laptops, 1 remote, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 wine glass, 2 cups, 2 chairs, 5 tvs, 2 laptops, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 backpack, 2 cups, 1 chair, 3 tvs, 5 laptops, 1 remote, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 cups, 4 tvs, 5 laptops, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 cups, 4 tvs, 3 laptops, 1 keyboard, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 2 chairs, 5 tvs, 2 laptops, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 cups, 1 dining table, 3 tvs, 6 laptops, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 1 chair, 2 tvs, 7 laptops, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 cup, 1 tv, 2 laptops, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 tvs, 1 laptop, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 cup, 1 dining table, 1 tv, 2 laptops, 10.7ms
# Speed: 2.6ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 backpack, 2 cups, 1 chair, 1 dining table, 4 tvs, 1 laptop, 1 book, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 1 chair, 1 dining table, 4 tvs, 2 laptops, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 1 chair, 3 tvs, 4 laptops, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 2 tvs, 3 laptops, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 cup, 2 tvs, 2 laptops, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 suitcase, 1 cup, 2 tvs, 3 laptops, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 1 cup, 4 tvs, 3 laptops, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 1 dining table, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 laptops, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 dining table, 1 laptop, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 chair, 1 tv, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 cup, 2 tvs, 2 laptops, 1 keyboard, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 2 chairs, 2 laptops, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 1 chair, 1 dining table, 1 laptop, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 1 laptop, 1 book, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 persons, 2 chairs, 4 laptops, 1 keyboard, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 chair, 1 tv, 2 laptops, 1 book, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1
 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 4 cups, 3 chairs, 4 tvs, 2 laptops, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 3 chairs, 4 tvs, 3 laptops, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 cups, 1 chair, 2 tvs, 1 laptop, 1 book, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 2 chairs, 2 tvs, 2 laptops, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 bottle, 2 cups, 3 chairs, 2 tvs, 2 laptops, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 3 chairs, 2 tvs, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 4 chairs, 2 tvs, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 4 chairs, 2 tvs, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 chairs, 4 tvs, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 5 chairs, 7 tvs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 2 chairs, 3 tvs, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 cup, 3 chairs, 3 tvs, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 3 chairs, 3 tvs, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 2 chairs, 2 tvs, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 cup, 2 chairs, 3 tvs, 10.7ms
# Speed: 3.4ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 2 chairs, 3 tvs, 1 laptop, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 2 chairs, 3 tvs, 1 laptop, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 4 tvs, 4 laptops, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 chair, 4 tvs, 4 laptops, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 2 chairs, 3 tvs, 3 laptops, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 2 chairs, 3 tvs, 3 laptops, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 cup, 3 tvs, 2 laptops, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 2 chairs, 4 tvs, 2 laptops, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 1 chair, 2 tvs, 2 laptops, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 1 chair, 3 tvs, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 2 chairs, 5 tvs, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 cups, 2 chairs, 1 dining table, 2 tvs, 1 laptop, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 bottle, 2 cups, 1 chair, 1 dining table, 5 tvs, 2 laptops, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 bottle, 1 cup, 8 tvs, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 1 bottle, 1 wine glass, 1 cup, 1 chair, 6 tvs, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 bottle, 1 cup, 7 tvs, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 1 bottle, 2 cups, 1 chair, 6 tvs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 1 bottle, 2 cups, 1 chair, 1 dining table, 6 tvs, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 1 bottle, 1 chair, 8 tvs, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 2 cups, 1 chair, 6 tvs, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 9 persons, 2 cups, 7 tvs, 2 laptops, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 9 persons, 2 cups, 1 chair, 1 dining table, 6 tvs, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 2 cups, 3 chairs, 1 dining table, 4 tvs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 6 tvs, 1 laptop, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 9 persons, 3 cups, 4 chairs, 2 dining tables, 3 tvs, 1 laptop, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 4 chairs, 1 dining table, 5 tvs, 3 laptops, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 1 cup, 2 chairs, 6 tvs, 2 laptops, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 2 chairs, 1 dining table, 4 tvs, 3 laptops, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 4 chairs, 1 dining table, 4 tvs, 1 laptop, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 4 cups, 3 chairs, 1 dining table, 3 tvs, 10.5ms
# Speed: 2.4ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 3 cups, 3 chairs, 1 dining table, 3 tvs, 2 laptops, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 3 cups, 2 chairs, 1 dining table, 3 tvs, 1 laptop, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 1 dining table, 3 tvs, 2 laptops, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 1 bottle, 3 cups, 1 chair, 1 dining table, 5 tvs, 1 laptop, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 2 cups, 2 chairs, 1 dining table, 4 tvs, 1 laptop, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 1 bottle, 3 cups, 1 chair, 1 dining table, 4 tvs, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 1 chair, 1 dining table, 4 tvs, 1 laptop, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 1 dining table, 3 tvs, 1 laptop, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 3 cups, 3 chairs, 1 dining table, 3 tvs, 2 laptops, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 2 chairs, 1 dining table, 5 tvs, 2 laptops, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 3 chairs, 1 dining table, 5 tvs, 1 laptop, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 4 chairs, 1 dining table, 4 tvs, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 3 cups, 6 chairs, 1 dining table, 6 tvs, 2 laptops, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 1 dining table, 6 tvs, 3 laptops, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 3 chairs, 1 dining table, 6 tvs, 3 laptops, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 2 chairs, 1 dining table, 7 tvs, 2 laptops, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 1 chair, 1 dining table, 7 tvs, 1 laptop, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 1 dining table, 8 tvs, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 1 dining table, 7 tvs, 2 laptops, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 5 chairs, 5 tvs, 10.6ms
# Speed: 3.1ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 1 cup, 4 chairs, 1 dining table, 5 tvs, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 5 chairs, 2 dining tables, 6 tvs, 1 laptop, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 3 chairs, 1 dining table, 3 tvs, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 2 chairs, 1 dining table, 4 tvs, 1 laptop, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 3 chairs, 1 dining table, 5 tvs, 4 laptops, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 3 cups, 5 chairs, 1 dining table, 4 tvs, 3 laptops, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 4 cups, 5 chairs, 1 dining table, 3 tvs, 3 laptops, 10.6ms
# Speed: 3.1ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 3 cups, 4 chairs, 1 dining table, 2 tvs, 1 laptop, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 4 chairs, 1 dining table, 7 tvs, 2 laptops, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 6 persons, 2 cups, 4 chairs, 6 tvs, 1 laptop, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 4 chairs, 1 dining table, 6 tvs, 1 laptop, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 2 chairs, 1 dining table, 7 tvs, 1 laptop, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 8 persons, 3 cups, 2 chairs, 1 dining table, 4 tvs, 2 laptops, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 3 chairs, 2 dining tables, 6 tvs, 2 laptops, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 3 cups, 2 chairs, 1 dining table, 6 tvs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 5 persons, 2 cups, 4 chairs, 8 tvs, 1 laptop, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 2 cups, 5 chairs, 5 tvs, 1 laptop, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 7 persons, 3 cups, 4 chairs, 1 dining table, 6 tvs, 3 laptops, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# ...
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 1 laptop, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 tvs, 2 laptops, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 tvs, 2 laptops, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 tvs, 2 laptops, 10.8ms
# Speed: 3.7ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 3 tvs, 1 laptop, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 1 tv, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 3 tvs, 1 mouse, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 tvs, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 5 tvs, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 3 tvs, 10.8ms
# Speed: 3.9ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 cups, 3 tvs, 1 cell phone, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 1 cell phone, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.7ms
# Speed: 2.8ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 2 tvs, 10.7ms
# Speed: 3.3ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 2 tvs, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 3 tvs, 1 cell phone, 10.6ms
# Speed: 3.2ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 handbag, 1 cup, 1 chair, 3 tvs, 1 cell phone, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 1 chair, 1 tv, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 3 tvs, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 1 chair, 2 tvs, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 1 cell phone, 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 2 tvs, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 backpack, 1 cup, 2 tvs, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 3 tvs, 1 laptop, 10.7ms
# Speed: 4.0ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 2 tvs, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 backpacks, 1 potted plant, 2 tvs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 backpacks, 2 tvs, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 backpack, 2 tvs, 10.6ms
# Speed: 3.1ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 1 tv, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 handbag, 1 cup, 3 tvs, 10.6ms
# Speed: 3.9ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 handbag, 1 cup, 2 tvs, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 2 tvs, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 3 tvs, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 10.7ms
# Speed: 4.1ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 11.3ms
# Speed: 3.3ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 3.1ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 3 tvs, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 backpack, 3 tvs, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 backpack, 3 tvs, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 tv, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 1 tv, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tie, 1 cup, 1 tv, 10.8ms
# Speed: 3.9ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 cups, 2 tvs, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 2 tvs, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 cup, 2 tvs, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 4.3ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 1 backpack, 2 tvs, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cake, 1 tv, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 4.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 4.0ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 3.2ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.6ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 3.2ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 cup, 1 tv, 10.6ms
# Speed: 3.7ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 1 tv, 10.6ms
# Speed: 4.1ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 backpack, 2 tvs, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
